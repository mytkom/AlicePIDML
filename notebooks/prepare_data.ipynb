# %%
# switch to the project directory
# %cd ..
# working directory should be **/pdi
# Out:
# /home/mkabus/pdi

# %%
import sys
import os
module_path = os.path.abspath('src')

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from pdi.data.preparation import MeanImputation
prep = MeanImputation()
prep.prepare_data()
prep.save_data()

# %%
from pdi.data.preparation import DeletePreparation
prep = DeletePreparation()
prep.prepare_data()
prep.save_data()

# %%
from pdi.data.preparation import RegressionImputation
prep = RegressionImputation()
prep.prepare_data()
prep.save_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-068d51c6d427> in <module>
#       1 from pdi.data.preparation import RegressionImputation
#       2 prep = RegressionImputation()
# ----> 3 prep.prepare_data()
#       4 prep.save_data()
#
# ~/pdi/src/pdi/data/utils.py in prepare_data(self)
#     145         split_data = self._test_train_split(data)
#     146         split_data_2 = self._input_target_split(split_data)
# --> 147         self._input_target, self._additional = self._do_process_data(
#     148             split_data_2)
#     149
#
# ~/pdi/src/pdi/data/preparation.py in _do_process_data(self, data)
#     129         complete = train_input.dropna()
#     130         self._regression.fit(complete.loc[:, ~self.missing_features &
# --> 131                                              (complete.columns != NSIGMA_COLUMNS)],
#     132                              complete.loc[:, self.missing_features])
#     133         self.regression_params = {
#
# ~/.virtualenvs/pdi/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# ~/.virtualenvs/pdi/lib/python3.9/site-packages/pandas/core/arraylike.py in __ne__(self, other)
#      42     @unpack_zerodim_and_defer("__ne__")
#      43     def __ne__(self, other):
# ---> 44         return self._cmp_method(other, operator.ne)
#      45
#      46     @unpack_zerodim_and_defer("__lt__")
#
# ~/.virtualenvs/pdi/lib/python3.9/site-packages/pandas/core/indexes/base.py in _cmp_method(self, other, op)
#    6777             # don't pass MultiIndex
#    6778             with np.errstate(all="ignore"):
# -> 6779                 result = ops.comp_method_OBJECT_ARRAY(op, self._values, other)
#    6780
#    6781         else:
#
# ~/.virtualenvs/pdi/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      77
#      78         if x.shape != y.shape:
# ---> 79             raise ValueError("Shapes must match", x.shape, y.shape)
#      80         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81     else:
#
# ValueError: ('Shapes must match', (29,), (10,))

# %%
from pdi.data.preparation import EnsemblePreparation
prep = EnsemblePreparation()
prep.prepare_data()
prep.save_data()

# %%
from pdi.data.preparation import FeatureSetPreparation
prep = FeatureSetPreparation()
prep.prepare_data()
prep.save_data()

# %% [markdown]
# ### Basic preparation for nsigma method

# %%
from pdi.data.utils import DataPreparation
prep = DataPreparation()
prep.prepare_data()
prep.save_data()
